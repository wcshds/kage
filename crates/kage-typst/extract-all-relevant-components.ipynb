# %%
with open("../../data/dump_newest_only.txt", encoding="utf8") as f:
    newest_data = f.readlines()
with open("../../data/dump_all_versions.txt", encoding="utf8") as f:
    all_version_data = f.readlines()

data = {}
name_list = []
for line in newest_data[2:-3]:
    tmp = line.split("|")

    name = tmp[0].strip()
    glyph_data = tmp[2].strip()

    data[name] = glyph_data
    name_list.append(name)

for line in all_version_data[2:-3]:
    tmp = line.split("|")

    name = tmp[0].strip().replace(r"\@", "@")
    glyph_data = tmp[2].strip()

    data[name] = glyph_data

# %%
def extract_all_relevant_components(name: str) -> dict[str, str]:
    glyph_data = data[name]
    result: dict[str, str] = {name: glyph_data}

    for line in glyph_data.split("$"):
        line = line.strip()
        if not line:
            continue

        fields = line.split(":")
        if not fields:
            continue

        if fields[0] == "99":
            component_name = fields[7].strip()

            if component_name and component_name not in result:
                sub_result = extract_all_relevant_components(component_name)
                result.update(sub_result)

    return result

name = "u2a1c4"
for key, value in extract_all_relevant_components(name).items():
    print(f"{key}:")
    for line in value.split("$"):
        print(f"  {line}")
    print()
# Out:
# u2a1c4:
#   99:0:0:0:0:200:200:u2a1c4-j
#
# u2a1c4-j:
#   99:0:0:7:0:112:200:u2ff1-cdp-8d44-u5375@8
#   99:0:0:38:0:197:200:u9ce5-02
#
# u2ff1-cdp-8d44-u5375@8:
#   99:0:0:0:4:200:153:cdp-8d44-03@2:0:0:0
#   99:0:0:6:88:188:194:u5375-j:0:0:0
#
# cdp-8d44-03@2:
#   99:200:-10:0:4:200:138:u58eb-03:0:0:-15
#   99:0:0:0:58:201:248:u5196-03-var-002@1
#   1:0:0:43:112:156:112
#
# u58eb-03:
#   1:0:0:16:48:184:48
#   1:0:32:100:14:100:88
#   1:0:0:28:88:172:88
#
# u5196-03-var-002@1:
#   2:7:8:31:16:32:53:16:65
#   1:0:2:32:31:176:31
#   2:22:7:176:31:174:38:165:60
#
# u5375-j:
#   99:0:0:-1:0:201:200:u20091-01
#   99:0:0:20:-7:200:199:u536a-02-var-001
#
# u20091-01:
#   2:0:7:99:22:67:35:35:40
#   1:12:32:35:40:35:139
#   2:0:7:17:148:52:137:87:124
#   7:0:7:88:49:88:112:88:170:29:187
#   2:7:8:47:64:64:76:70:99
#
# u536a-02-var-001:
#   99:0:0:0:0:200:200:u5369-02-var-001
#   99:0:0:80:5:197:174:u4e36-j
#
# u5369-02-var-001:
#   1:2:2:111:42:171:42
#   1:22:4:171:42:171:153
#   1:12:0:111:42:111:188
#
# u4e36-j:
#   2:7:8:73:77:106:93:116:120
#
# u9ce5-02:
#   99:0:0:0:0:200:200:cdp-8cbb-02
#   2:7:8:97:135:100:161:87:172
#   2:7:8:111:138:119:155:115:167
#   2:7:8:126:137:137:145:137:160
#   2:7:8:141:134:155:139:157:151
#
# cdp-8cbb-02:
#   2:0:7:136:14:131:27:124:38
#   1:12:13:100:38:100:122
#   1:2:2:100:38:164:38
#   1:22:23:164:38:164:82
#   1:2:2:100:60:164:60
#   1:2:2:100:82:164:82
#   1:2:0:100:102:186:102
#   1:2:2:100:122:176:122
#   2:22:4:176:122:177:164:163:182
